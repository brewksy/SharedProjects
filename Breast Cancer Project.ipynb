# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
from sklearn.preprocessing import OneHotEncoder
ohencoder = OneHotEncoder()
import datetime

# %%
df = pd.read_csv('data.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
#check for missing values
df.isnull().sum(axis = 0)
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Drop un-needed columns
df = df.drop(columns=['id','Unnamed: 32'])

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# Encoding and Scaling
# y = df.iloc[:, 0].values
# selected_X = df.iloc[:, 1:30].values
# encoded_y = encoder.fit_transform(y)
# encoded_X = ohencoder.fit_transform(selected_X)

# %%
# Encoding the Diagnosis Column
df['diagnosis']= encoder.fit_transform(df['diagnosis'])
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# Scaling Every other column
df.iloc[:,1:31] = scaler.fit_transform(df.iloc[:,1:31])
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1     1.097064     -2.073335        1.269934   0.984375
# 1            1     1.829821     -0.353632        1.685955   1.908708
# 2            1     1.579888      0.456187        1.566503   1.558884
# 3            1    -0.768909      0.253732       -0.592687  -0.764464
# 4            1     1.750297     -1.151816        1.776573   1.826229
# ..         ...          ...           ...             ...        ...
# 564          1     2.110995      0.721473        2.060786   2.343856
# 565          1     1.704854      2.085134        1.615931   1.723842
# 566          1     0.702284      2.045574        0.672676   0.577953
# 567          1     1.838341      2.336457        1.982524   1.735218
# 568          0    -1.808401      1.221792       -1.814389  -1.347789
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.mean()
# All values are averaged around 0
# Out:
# diagnosis                  3.725835e-01
# radius_mean               -1.256562e-16
# texture_mean               1.049736e-16
# perimeter_mean            -1.272171e-16
# area_mean                 -1.900452e-16
# smoothness_mean            1.490704e-16
# compactness_mean           2.544342e-16
# concavity_mean            -1.338511e-16
# concave points_mean       -8.429110e-17
# symmetry_mean              2.081912e-16
# fractal_dimension_mean     5.408679e-16
# radius_se                  2.475807e-16
# texture_se                -9.912009e-17
# perimeter_se              -2.968237e-16
# area_se                   -1.088760e-16
# smoothness_se              4.426014e-16
# compactness_se             1.958988e-16
# concavity_se               1.678017e-16
# concave points_se          2.185325e-17
# symmetry_se                1.523874e-16
# fractal_dimension_se      -5.658430e-17
# radius_worst              -7.988142e-16
# texture_worst             -1.834112e-17
# ...

# %%
# no NaN values
df.isnull().sum(axis = 0)
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# %matplotlib inline

# %%
for column_number in range (1,31):
    plt.yticks(ticks=[0,1])
    plt.title('Scatter Plot Correlation')
    plt.xlabel(df.columns[column_number])
    plt.ylabel("Diagnosis")
    plt.scatter(df.iloc[:,column_number],df.iloc[:,0], color='red', alpha=0.05)
    plt.show()

# %%
import seaborn as sns

# %%
sns.heatmap(data= df.corr())

# %%
for column_number in range (1,31):
    sns.boxplot(x=df.columns[column_number], data= df)
    plt.show()

# %%
for column_number in range (1,31):
    sns.violinplot(x=df.columns[column_number], data= df)
    plt.show()

# %%
# I would contend that the compactness_mean violin plot may have an outlier
# There is an anomaly in the data on the right that seems to get larger and is out of the normal distribution of points
